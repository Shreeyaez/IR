# %%
import pandas as pd

data = {
    "Employee Name": ["Sujan","John", "Alice", "Bob", "Yere", "Michael", "Sarah", "David", "Linda", "Emily", 
                      "Robert", "Sophia", "Daniel", "Olivia", "James", "Emma", "William", "Ava", "Joseph", "Cia"],
    "Review": [
        "Omg! Amazing sound! 🔊 Love the bass <b>quality</b> 😍",
        "It’s gud but sometimez disconnects?? 🤷‍♂️",
        "Buy it now!!! 👉 <a href='https://example.com/earbuds'>Click here</a> 🎧",
        "Decent earbds, bt the charging case iz flimsy 💼",
        "Perfct for gym imo 🏋️‍♀️<i>and running</i>. No issues so far!",
        "Battery 💣!!! Drains too fast. https://bit.ly/bt-fail",
        "GReat connection 📶 and 💬 call clarity!",
        "😤 btw Not workin after 2 weekz. waste of $$",
        "👍👍 Value 4 money. Fit is <span style='color:green;'>gr8</span>.",
        "Came in 📦 fast. <u>Noise cancellation</u> is real 🔇",
        "Didn't match color shown online smh 😡🤯",
        "So 💕 comfy! Wore it 4 hours straight. <br>Zero pain.",
        "Audio skips!! 😒 <a href='https://support.com'>Need help</a>",
        "❌❌❌ Disapointing experience. Never again.",
        "🔥🔥🔥 Loud & crisp. But case scratches ez",
        "Good for <b>Zoom</b> calls. Voice clear 😌",
        "Gave me ear rash??!! 😖 idk if it's just me",
        "🎵🎶 Music sounds alive! <i>Even classical!</i>",
        "It’s okay, nothin special tbh. Box was 💔 damaged tho",
        "I love these 😍! Bought a pair for mom too 👉 <a href='http://earbuds.com'>shop now</a>"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#    Employee Name                                             Review
# 0          Sujan  Omg! Amazing sound! 🔊 Love the bass <b>quality...
# 1           John          It’s gud but sometimez disconnects?? 🤷‍♂️
# 2          Alice  Buy it now!!! 👉 <a href='https://example.com/e...
# 3            Bob    Decent earbds, bt the charging case iz flimsy 💼
# 4           Yere  Perfct for gym imo 🏋️‍♀️<i>and running</i>. No...
# 5        Michael  Battery 💣!!! Drains too fast. https://bit.ly/b...
# 6          Sarah             GReat connection 📶 and 💬 call clarity!
# 7          David        😤 btw Not workin after 2 weekz. waste of $$
# 8          Linda  👍👍 Value 4 money. Fit is <span style='color:gr...
# 9          Emily  Came in 📦 fast. <u>Noise cancellation</u> is r...
# 10        Robert             Didn't match color shown online smh 😡🤯
# 11        Sophia  So 💕 comfy! Wore it 4 hours straight. <br>Zero...
# 12        Daniel  Audio skips!! 😒 <a href='https://support.com'>...
# ...

# %%
df = df[['Review']]
df
# Out:
#                                                Review
# 0       omg! amazing sound! 🔊 love the bass quality 😍
# 1           it’s gud but sometimez disconnects?? 🤷‍♂️
# 2                        buy it now!!! 👉 click here 🎧
# 3     decent earbds, bt the charging case iz flimsy 💼
# 4   perfct for gym in my opinion 🏋️‍♀️and running....
# 5   battery 💣!!! drains too fast. https://bit.ly/b...
# 6              great connection 📶 and 💬 call clarity!
# 7   😤 by the way not workin after 2 weekz. waste o...
# 8                       👍👍 value 4 money. fit is gr8.
# 9        came in 📦 fast. noise cancellation is real 🔇
# 10  didn't match color shown online shaking my hea...
# 11   so 💕 comfy! wore it 4 hours straight. zero pain.
# 12                          audio skips!! 😒 need help
# 13          ❌❌❌ disapointing experience. never again.
# 14          🔥🔥🔥 loud & crisp. but case scratches easy
# 15                 good for zoom calls. voice clear 😌
# ...

# %%
full_form_dict = {
    'omg': 'oh my god',
    'tbh': 'to be honest',
    'imo': 'in my opinion',
    'smh': 'shaking my head',
    'ez': 'easy', 
    'btw': 'by the way',
    'gr8': 'great'
}

def correct_short_forms(text):

    words = text.split()
    corrected_words = [full_form_dict.get(word, word) for word in words]
    corrected_text = ' '.join(corrected_words)

    return corrected_text

df['Review'] = df['Review'].apply(correct_short_forms)
df
# Out:
#                                                Review
# 0       omg! amazing sound! 🔊 love the bass quality 😍
# 1           it’s gud but sometimez disconnects?? 🤷‍♂️
# 2                        buy it now!!! 👉 click here 🎧
# 3     decent earbds, bt the charging case iz flimsy 💼
# 4   perfct for gym in my opinion 🏋️‍♀️and running....
# 5   battery 💣!!! drains too fast. https://bit.ly/b...
# 6              great connection 📶 and 💬 call clarity!
# 7   😤 by the way not workin after 2 weekz. waste o...
# 8                       👍👍 value 4 money. fit is gr8.
# 9        came in 📦 fast. noise cancellation is real 🔇
# 10  didn't match color shown online shaking my hea...
# 11   so 💕 comfy! wore it 4 hours straight. zero pain.
# 12                          audio skips!! 😒 need help
# 13          ❌❌❌ disapointing experience. never again.
# 14          🔥🔥🔥 loud & crisp. but case scratches easy
# 15                 good for zoom calls. voice clear 😌
# ...

# %%
df['Review'] = df['Review'].str.lower()
df.head(5)
# Out:
#                                               Review
# 0      omg! amazing sound! 🔊 love the bass quality 😍
# 1          it’s gud but sometimez disconnects?? 🤷‍♂️
# 2                       buy it now!!! 👉 click here 🎧
# 3    decent earbds, bt the charging case iz flimsy 💼
# 4  perfct for gym in my opinion 🏋️‍♀️and running....

# %%
import re
def remove_html_tags(text):
    pattern = re.compile(r'<.*?>')
    return pattern.sub('', text)

# %%
df['Review'] = df['Review'].apply(lambda text: remove_html_tags(text))

# %%
df['Review'][1]
# Out:
# 'it’s gud but sometimez disconnects?? 🤷\u200d♂️'

# %%
def remove_url(text):
    pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    return pattern.sub(r'', text)

df['Review'] = df['Review'].apply(remove_url)

# %%
df['Review'][5]
# Out:
# 'battery 💣!!! drains too fast. '

# %%
import string

def remove_punctuation(text):
    pattern = re.compile(f"[{re.escape(string.punctuation)}]")
    return pattern.sub(r'', text)

df['Review'] = df['Review'].apply(remove_punctuation)
df.head()
# Out:
#                                               Review
# 0        omg amazing sound 🔊 love the bass quality 😍
# 1            it’s gud but sometimez disconnects 🤷‍♂️
# 2                          buy it now 👉 click here 🎧
# 3     decent earbds bt the charging case iz flimsy 💼
# 4  perfct for gym in my opinion 🏋️‍♀️and running ...

# %%
from textblob import TextBlob

def correct_spelling(text):
    textBLB = TextBlob(text)
    return textBLB.correct().string

df['Review'] = df['Review'].apply(correct_spelling)

# %%
df['Review'][13]
# Out:
# '❌❌❌ disappointing experience never again'

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('punkt')

nltk.download('stopwords')

from nltk.tokenize import word_tokenize,sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words= set(stopwords.words('english'))

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
def removing_stopwords(text):
    stop_words = set(stopwords.words('english'))
    words = word_tokenize(text)
    filtered_words = [word for word in words if word.lower() not in stop_words]
    filtered_sentences = ' '.join(filtered_words)
    
    return filtered_sentences


df['Review'] = df['Review'].apply(removing_stopwords)
df.head(3)
# Out:
#                                 Review
# 0  org amazing sound love bass quality
# 1     ’ god sometimes disconnected ‍♂️
# 2                            buy click

# %%
def remove_emojis(text):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # Emojis
                               u"\U0001F300-\U0001F5FF"  # Symbols & Pictographs
                               u"\U0001F680-\U0001F6FF"  # Transport & Map Symbols
                               u"\U0001F700-\U0001F77F"  # Alchemical Symbols
                               u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                               u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                               u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                               u"\U0001FA00-\U0001FA6F"  # Chess Symbols
                               u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                               u"\U0001FB00-\U0001FBFF"  # Symbols for Legacy Computing
                               u"\U0001F004-\U0001F0CF"  # Miscellaneous Symbols and Arrows
                               u"\U0001F10D-\U0001F10F"  # Enclosed Alphanumeric Supplement
                               u"\U0001F200-\U0001F251"  # Enclosed Ideographic Supplement
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)


df['Review'] = df['Review'].apply(remove_emojis)

# %%
df['Review'][6]
# Out:
# 'great connection call clarity'

# %%
EMOTICONS = {
    u":‑\)":"Happy face or smiley",
    u":\)":"Happy face or smiley",
    u":-\]":"Happy face or smiley",
    u":\]":"Happy face or smiley",
    u":-3":"Happy face smiley",
    u":3":"Happy face smiley",
    u":->":"Happy face smiley",
    u":>":"Happy face smiley",
    u"8-\)":"Happy face smiley",
    u":o\)":"Happy face smiley",
    u":-\}":"Happy face smiley",
    u":\}":"Happy face smiley",
    u":-\)":"Happy face smiley",
    u":c\)":"Happy face smiley",
    u":\^\)":"Happy face smiley",
    u"=\]":"Happy face smiley",
    u"=\)":"Happy face smiley",
    u":‑D":"Laughing, big grin or laugh with glasses",
    u":D":"Laughing, big grin or laugh with glasses",
    u"8‑D":"Laughing, big grin or laugh with glasses",
    u"8D":"Laughing, big grin or laugh with glasses",
    u"X‑D":"Laughing, big grin or laugh with glasses",
    u"XD":"Laughing, big grin or laugh with glasses",
    u"=D":"Laughing, big grin or laugh with glasses",
    u"=3":"Laughing, big grin or laugh with glasses",
    u"B\^D":"Laughing, big grin or laugh with glasses",
    u":-\)\)":"Very happy",
    u":‑\(":"Frown, sad, andry or pouting",
    u":-\(":"Frown, sad, andry or pouting",
    u":\(":"Frown, sad, andry or pouting",
    u":‑c":"Frown, sad, andry or pouting",
    u":c":"Frown, sad, andry or pouting",
    u":‑<":"Frown, sad, andry or pouting",
    u":<":"Frown, sad, andry or pouting",
    u":‑\[":"Frown, sad, andry or pouting",
    u":\[":"Frown, sad, andry or pouting",
    u":-\|\|":"Frown, sad, andry or pouting",
    u">:\[":"Frown, sad, andry or pouting",
    u":\{":"Frown, sad, andry or pouting",
    u":@":"Frown, sad, andry or pouting",
    u">:\(":"Frown, sad, andry or pouting",
    u":'‑\(":"Crying",
    u":'\(":"Crying",
    u":'‑\)":"Tears of happiness",
    u":'\)":"Tears of happiness",
    u"D‑':":"Horror",
    u"D:<":"Disgust",
    u"D:":"Sadness",
    u"D8":"Great dismay",
    u"D;":"Great dismay",
    u"D=":"Great dismay",
    u"DX":"Great dismay",
    u":‑O":"Surprise",
    u":O":"Surprise",
    u":‑o":"Surprise",
    u":o":"Surprise",
    u":-0":"Shock",
    u"8‑0":"Yawn",
    u">:O":"Yawn",
    u":-\*":"Kiss",
    u":\*":"Kiss",
    u":X":"Kiss",
    u";‑\)":"Wink or smirk",
    u";\)":"Wink or smirk",
    u"\*-\)":"Wink or smirk",
    u"\*\)":"Wink or smirk",
    u";‑\]":"Wink or smirk",
    u";\]":"Wink or smirk",
    u";\^\)":"Wink or smirk",
    u":‑,":"Wink or smirk",
    u";D":"Wink or smirk",
    u":‑P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"X‑P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"XP":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":‑Þ":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":Þ":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":b":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"d:":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"=p":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u">:P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":‑/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":-[.]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u">:[(\\\)]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u">:/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":[(\\\)]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=[(\\\)]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":L":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=L":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":S":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":‑\|":"Straight face",
    u":\|":"Straight face",
    u":$":"Embarrassed or blushing",
    u":‑x":"Sealed lips or wearing braces or tongue-tied",
    u":x":"Sealed lips or wearing braces or tongue-tied",
    u":‑#":"Sealed lips or wearing braces or tongue-tied",
    u":#":"Sealed lips or wearing braces or tongue-tied",
    u":‑&":"Sealed lips or wearing braces or tongue-tied",
    u":&":"Sealed lips or wearing braces or tongue-tied",
    u"O:‑\)":"Angel, saint or innocent",
    u"O:\)":"Angel, saint or innocent",
    u"0:‑3":"Angel, saint or innocent",
    u"0:3":"Angel, saint or innocent",
    u"0:‑\)":"Angel, saint or innocent",
    u"0:\)":"Angel, saint or innocent",
    u":‑b":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"0;\^\)":"Angel, saint or innocent",
    u">:‑\)":"Evil or devilish",
    u">:\)":"Evil or devilish",
    u"\}:‑\)":"Evil or devilish",
    u"\}:\)":"Evil or devilish",
    u"3:‑\)":"Evil or devilish",
    u"3:\)":"Evil or devilish",
    u">;\)":"Evil or devilish",
    u"\|;‑\)":"Cool",
    u"\|‑O":"Bored",
    u":‑J":"Tongue-in-cheek",
    u"#‑\)":"Party all night",
    u"%‑\)":"Drunk or confused",
    u"%\)":"Drunk or confused",
    u":-###..":"Being sick",
    u":###..":"Being sick",
    u"<:‑\|":"Dump",
    u"\(>_<\)":"Troubled",
    u"\(>_<\)>":"Troubled",
    u"\(';'\)":"Baby",
    u"\(\^\^>``":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(\^_\^;\)":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(-_-;\)":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(~_~;\) \(・\.・;\)":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(-_-\)zzz":"Sleeping",
    u"\(\^_-\)":"Wink",
    u"\(\(\+_\+\)\)":"Confused",
    u"\(\+o\+\)":"Confused",
    u"\(o\|o\)":"Ultraman",
    u"\^_\^":"Joyful",
    u"\(\^_\^\)/":"Joyful",
    u"\(\^O\^\)／":"Joyful",
    u"\(\^o\^\)／":"Joyful",
    u"\(__\)":"Kowtow as a sign of respect, or dogeza for apology",
    u"_\(\._\.\)_":"Kowtow as a sign of respect, or dogeza for apology",
    u"<\(_ _\)>":"Kowtow as a sign of respect, or dogeza for apology",
    u"<m\(__\)m>":"Kowtow as a sign of respect, or dogeza for apology",
    u"m\(__\)m":"Kowtow as a sign of respect, or dogeza for apology",
    u"m\(_ _\)m":"Kowtow as a sign of respect, or dogeza for apology",
    u"\('_'\)":"Sad or Crying",
    u"\(/_;\)":"Sad or Crying",
    u"\(T_T\) \(;_;\)":"Sad or Crying",
    u"\(;_;":"Sad of Crying",
    u"\(;_:\)":"Sad or Crying",
    u"\(;O;\)":"Sad or Crying",
    u"\(:_;\)":"Sad or Crying",
    u"\(ToT\)":"Sad or Crying",
    u";_;":"Sad or Crying",
    u";-;":"Sad or Crying",
    u";n;":"Sad or Crying",
    u";;":"Sad or Crying",
    u"Q\.Q":"Sad or Crying",
    u"T\.T":"Sad or Crying",
    u"QQ":"Sad or Crying",
    u"Q_Q":"Sad or Crying",
    u"\(-\.-\)":"Shame",
    u"\(-_-\)":"Shame",
    u"\(一一\)":"Shame",
    u"\(；一_一\)":"Shame",
    u"\(=_=\)":"Tired",
    u"\(=\^\·\^=\)":"cat",
    u"\(=\^\·\·\^=\)":"cat",
    u"=_\^=	":"cat",
    u"\(\.\.\)":"Looking down",
    u"\(\._\.\)":"Looking down",
    u"\^m\^":"Giggling with hand covering mouth",
    u"\(\・\・?":"Confusion",
    u"\(?_?\)":"Confusion",
    u">\^_\^<":"Normal Laugh",
    u"<\^!\^>":"Normal Laugh",
    u"\^/\^":"Normal Laugh",
    u"\（\*\^_\^\*）" :"Normal Laugh",
    u"\(\^<\^\) \(\^\.\^\)":"Normal Laugh",
    u"\(^\^\)":"Normal Laugh",
    u"\(\^\.\^\)":"Normal Laugh",
    u"\(\^_\^\.\)":"Normal Laugh",
    u"\(\^_\^\)":"Normal Laugh",
    u"\(\^\^\)":"Normal Laugh",
    u"\(\^J\^\)":"Normal Laugh",
    u"\(\*\^\.\^\*\)":"Normal Laugh",
    u"\(\^—\^\）":"Normal Laugh",
    u"\(#\^\.\^#\)":"Normal Laugh",
    u"\（\^—\^\）":"Waving",
    u"\(;_;\)/~~~":"Waving",
    u"\(\^\.\^\)/~~~":"Waving",
    u"\(-_-\)/~~~ \($\·\·\)/~~~":"Waving",
    u"\(T_T\)/~~~":"Waving",
    u"\(ToT\)/~~~":"Waving",
    u"\(\*\^0\^\*\)":"Excited",
    u"\(\*_\*\)":"Amazed",
    u"\(\*_\*;":"Amazed",
    u"\(\+_\+\) \(@_@\)":"Amazed",
    u"\(\*\^\^\)v":"Laughing,Cheerful",
    u"\(\^_\^\)v":"Laughing,Cheerful",
    u"\(\(d[-_-]b\)\)":"Headphones,Listening to music",
    u'\(-"-\)':"Worried",
    u"\(ーー;\)":"Worried",
    u"\(\^0_0\^\)":"Eyeglasses",
    u"\(\＾ｖ\＾\)":"Happy",
    u"\(\＾ｕ\＾\)":"Happy",
    u"\(\^\)o\(\^\)":"Happy",
    u"\(\^O\^\)":"Happy",
    u"\(\^o\^\)":"Happy",
    u"\)\^o\^\(":"Happy",
    u":O o_O":"Surprised",
    u"o_0":"Surprised",
    u"o\.O":"Surpised",
    u"\(o\.o\)":"Surprised",
    u"oO":"Surprised",
    u"\(\*￣m￣\)":"Dissatisfied",
    u"\(‘A`\)":"Snubbed or Deflated"
}

# %%
def remove_emoticons(text):
    emoticon_pattern = re.compile(u'(' + u'|'.join(k for k in EMOTICONS) + u')')
    return emoticon_pattern.sub(r'', text)

df['Review'] = df['Review'].apply(remove_emoticons)

# %%
df['Review'][6]
# Out:
# 'great connection call clarity'

# %%
normal_text = "AI is getting smarter and can now make new things like art and stories."
normal_para = "AI is getting smarter and can now make new things like art and stories. This changes how people create and design."

# %%
# work tokenization
tokenize1 = normal_text.split()
tokenize1
# Out:
# ['AI',
#  'is',
#  'getting',
#  'smarter',
#  'and',
#  'can',
#  'now',
#  'make',
#  'new',
#  'things',
#  'like',
#  'art',
#  'and',
#  'stories.']

# %%
# sentence tokenization
tokenize2 = normal_para.split(".")
tokenize2
# Out:
# ['AI is getting smarter and can now make new things like art and stories',
#  ' This changes how people create and design',
#  '']

# %%
import re
tokenize3 = re.findall("[\w']+",normal_text)
tokenize3
# Out:
# ['AI',
#  'is',
#  'getting',
#  'smarter',
#  'and',
#  'can',
#  'now',
#  'make',
#  'new',
#  'things',
#  'like',
#  'art',
#  'and',
#  'stories']

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
word_tokenize(normal_text)
# Out:
# ['AI',
#  'is',
#  'getting',
#  'smarter',
#  'and',
#  'can',
#  'now',
#  'make',
#  'new',
#  'things',
#  'like',
#  'art',
#  'and',
#  'stories',
#  '.']

# %%
sent_tokenize(normal_para)
# Out:
# ['AI is getting smarter and can now make new things like art and stories.',
#  'This changes how people create and design.']

# %%
# !python -m spacy download en_core_web_sm
import spacy
nlp = spacy.load('en_core_web_sm')
tokenize4 = nlp(normal_text)
tokenize4
# Out:
# AI is getting smarter and can now make new things like art and stories.

# %%
for token in tokenize4:
    print(token)
# Out:
# AI
# is
# getting
# smarter
# and
# can
# now
# make
# new
# things
# like
# art
# and
# stories
# .

# %%
def spacy_tokenize(text):
    nlp = spacy.load('en_core_web_sm')
    tokenize_value = nlp(text)
    return tokenize_value

df['Review'] = df['Review'].apply(spacy_tokenize)

# %%
df.head(3)
# Out:
#                                        Review
# 0  (org, amazing, sound, love, bass, quality)
# 1  (’, god, sometimes, disconnected, ‍, ♂, ️)
# 2                                (buy, click)

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
nlp = spacy.load('en_core_web_sm')

def apply_stemming(text):
    
    tokenize_value = nlp(text)
    
    stemmed_words =  [stemmer.stem(token.text) for token in tokenize_value]
    stemmed_text = ' '.join(stemmed_words)
    return stemmed_text

df['Review'] = df['Review'].apply(apply_stemming)

# %%
df.head(3)
# Out:
#                              Review
# 0  org amaz sound love bass qualiti
# 1    ’ god sometim disconnect ‍ ♂ ️
# 2                         buy click

# %%
pd.set_option('display.max_colwidth', None)
df
# Out:
#                                         Review
# 0             org amaz sound love bass qualiti
# 1               ’ god sometim disconnect ‍ ♂ ️
# 2                                    buy click
# 3                    decent ear charg case fli
# 4   perfect grm opinion ️‍ ♀ ️and run issu far
# 5                           batteri drain fast
# 6                   great connect call clariti
# 7                         way work 2 week wast
# 8                         valu 4 money fit grm
# 9                   came fast nois cancel real
# 10          match color shown onlin shake head
# 11         come wore 4 hour straight zero pain
# 12                        audit ship need help
# 13               ❌ ❌ ❌ disappoint experi never
# 14                loud crisp case scratch easi
# 15                   good room call voic clear
# 16                           gave ear rash ink
# 17               music sound aliv even classic
# 18            ’ okay noth special th box damag
# ...
